# %%
from pathlib import Path

# %%
path = Path("./../dl/1/HousingData.csv")

# %%
import pandas as pd

# %%
df = pd.read_csv(path)

# %%
df
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# 2       17.8  392.83   4.03  34.7
# 3       18.7  394.63   2.94  33.4
# 4       18.7  396.90    NaN  36.2
# ..       ...     ...    ...   ...
# 501     21.0  391.99    NaN  22.4
# 502     21.0  396.90   9.08  20.6
# 503     21.0  396.90   5.64  23.9
# 504     21.0  393.45   6.48  22.0
# 505     21.0  396.90   7.88  11.9
#
# [506 rows x 14 columns]

# %%
df.isna().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
df.fillna(df.mean(numeric_only=True), inplace=True)
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM        AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.200000  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.900000  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.100000  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.800000  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.200000  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...        ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.100000  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.700000  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.000000  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.300000  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  68.518519  2.5050    1  273
#
#      PTRATIO       B      LSTAT  MEDV
# 0       15.3  396.90   4.980000  24.0
# 1       17.8  396.90   9.140000  21.6
# 2       17.8  392.83   4.030000  34.7
# 3       18.7  394.63   2.940000  33.4
# 4       18.7  396.90  12.715432  36.2
# ..       ...     ...        ...   ...
# 501     21.0  391.99  12.715432  22.4
# 502     21.0  396.90   9.080000  20.6
# 503     21.0  396.90   5.640000  23.9
# 504     21.0  393.45   6.480000  22.0
# 505     21.0  396.90   7.880000  11.9
#
# [506 rows x 14 columns]

# %%
df.isna().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
x = df.drop("MEDV", axis=1)

# %%
y = df.MEDV

# %%
x.shape
# Out:
# (506, 13)

# %%
y.shape
# Out:
# (506,)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
x_train_scaled = sc.fit_transform(x_train)
x_test_scaled = sc.transform(x_test)

# %%
import tensorflow as tf
from tensorflow.keras import Sequential, layers

# %%
model = Sequential([
    layers.Input(shape=(x_train_scaled.shape[1],)),
    layers.Dense(32, activation="relu"),
    layers.Dense(64, activation="relu"),
    layers.Dense(1)
])

# %%
model.compile(
    optimizer="adam",
    loss="mse",
    metrics=[
        tf.keras.metrics.MeanSquaredError,
        tf.keras.metrics.MeanAbsoluteError
    ]
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
history = model.fit(
    x_train_scaled,
    y_train,
    epochs=100,
    batch_size=16,
    validation_split=0.2,
)
# Out:
# Epoch 1/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 607.1395 - mean_absolute_error: 22.7440 - mean_squared_error: 607.1395 - val_loss: 523.8653 - val_mean_absolute_error: 21.3399 - val_mean_squared_error: 523.8653
# Epoch 2/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 552.4042 - mean_absolute_error: 21.5127 - mean_squared_error: 552.4042 - val_loss: 464.1308 - val_mean_absolute_error: 19.9217 - val_mean_squared_error: 464.1308
# Epoch 3/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 471.4983 - mean_absolute_error: 19.5898 - mean_squared_error: 471.4983 - val_loss: 363.2556 - val_mean_absolute_error: 17.3210 - val_mean_squared_error: 363.2556
# Epoch 4/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 341.3809 - mean_absolute_error: 16.1269 - mean_squared_error: 341.3809 - val_loss: 224.7849 - val_mean_absolute_error: 13.0996 - val_mean_squared_error: 224.7849
# Epoch 5/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 193.2239 - mean_absolute_error: 11.3047 - mean_squared_error: 193.2239 - val_loss: 101.4050 - val_mean_absolute_error: 7.8741 - val_mean_squared_error: 101.4050
# Epoch 6/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 102.5830 - mean_absolute_error: 7.9477 - mean_squared_error: 102.5830 - val_loss: 53.8737 - val_mean_absolute_error: 5.4797 - val_mean_squared_error: 53.8737
# Epoch 7/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 66.3219 - mean_absolute_error: 6.3337 - mean_squared_error: 66.3219 - val_loss: 37.3634 - val_mean_absolute_error: 4.4753 - val_mean_squared_error: 37.3634
# Epoch 8/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 45.6548 - mean_absolute_error: 5.1905 - mean_squared_error: 45.6548 - val_loss: 29.3245 - val_mean_absolute_error: 3.8495 - val_mean_squared_error: 29.3245
# Epoch 9/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 34.1763 - mean_absolute_error: 4.4283 - mean_squared_error: 34.1763 - val_loss: 26.8463 - val_mean_absolute_error: 3.7026 - val_mean_squared_error: 26.8463
# Epoch 10/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 28.2678 - mean_absolute_error: 4.0054 - mean_squared_error: 28.2678 - val_loss: 25.4701 - val_mean_absolute_error: 3.5741 - val_mean_squared_error: 25.4701
# Epoch 11/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 25.3960 - mean_absolute_error: 3.7812 - mean_squared_error: 25.3960 - val_loss: 24.9165 - val_mean_absolute_error: 3.5474 - val_mean_squared_error: 24.9165
# Epoch 12/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 23.8073 - mean_absolute_error: 3.6546 - mean_squared_error: 23.8073 - val_loss: 24.8403 - val_mean_absolute_error: 3.5684 - val_mean_squared_error: 24.8403
# Epoch 13/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 22.4388 - mean_absolute_error: 3.5370 - mean_squared_error: 22.4388 - val_loss: 24.8362 - val_mean_absolute_error: 3.5694 - val_mean_squared_error: 24.8362
# Epoch 14/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 21.5051 - mean_absolute_error: 3.4205 - mean_squared_error: 21.5051 - val_loss: 24.1831 - val_mean_absolute_error: 3.5119 - val_mean_squared_error: 24.1831
# Epoch 15/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 20.7048 - mean_absolute_error: 3.3746 - mean_squared_error: 20.7048 - val_loss: 23.4915 - val_mean_absolute_error: 3.4466 - val_mean_squared_error: 23.4915
# Epoch 16/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 19.9030 - mean_absolute_error: 3.2928 - mean_squared_error: 19.9030 - val_loss: 23.0388 - val_mean_absolute_error: 3.4159 - val_mean_squared_error: 23.0388
# Epoch 17/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 19.2651 - mean_absolute_error: 3.2458 - mean_squared_error: 19.2651 - val_loss: 22.8534 - val_mean_absolute_error: 3.4260 - val_mean_squared_error: 22.8534
# Epoch 18/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 18.7754 - mean_absolute_error: 3.1900 - mean_squared_error: 18.7754 - val_loss: 22.3965 - val_mean_absolute_error: 3.3890 - val_mean_squared_error: 22.3965
# Epoch 19/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 18.1249 - mean_absolute_error: 3.1407 - mean_squared_error: 18.1249 - val_loss: 21.8212 - val_mean_absolute_error: 3.3392 - val_mean_squared_error: 21.8212
# Epoch 20/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 17.6004 - mean_absolute_error: 3.0823 - mean_squared_error: 17.6004 - val_loss: 21.5597 - val_mean_absolute_error: 3.3474 - val_mean_squared_error: 21.5597
# Epoch 21/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 17.0474 - mean_absolute_error: 3.0268 - mean_squared_error: 17.0474 - val_loss: 21.2967 - val_mean_absolute_error: 3.3412 - val_mean_squared_error: 21.2967
# Epoch 22/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 16.6583 - mean_absolute_error: 2.9764 - mean_squared_error: 16.6583 - val_loss: 20.6770 - val_mean_absolute_error: 3.2868 - val_mean_squared_error: 20.6770
# Epoch 23/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 16.3064 - mean_absolute_error: 2.9636 - mean_squared_error: 16.3064 - val_loss: 20.5554 - val_mean_absolute_error: 3.3151 - val_mean_squared_error: 20.5554
# Epoch 24/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 15.7314 - mean_absolute_error: 2.8871 - mean_squared_error: 15.7314 - val_loss: 20.1897 - val_mean_absolute_error: 3.2735 - val_mean_squared_error: 20.1897
# Epoch 25/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 15.4900 - mean_absolute_error: 2.8387 - mean_squared_error: 15.4900 - val_loss: 20.2689 - val_mean_absolute_error: 3.2891 - val_mean_squared_error: 20.2689
# Epoch 26/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 15.1515 - mean_absolute_error: 2.8274 - mean_squared_error: 15.1515 - val_loss: 20.0245 - val_mean_absolute_error: 3.2786 - val_mean_squared_error: 20.0245
# Epoch 27/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 14.7720 - mean_absolute_error: 2.7952 - mean_squared_error: 14.7720 - val_loss: 19.6262 - val_mean_absolute_error: 3.2423 - val_mean_squared_error: 19.6262
# Epoch 28/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 14.4206 - mean_absolute_error: 2.7516 - mean_squared_error: 14.4206 - val_loss: 19.5308 - val_mean_absolute_error: 3.2394 - val_mean_squared_error: 19.5308
# Epoch 29/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 14.2735 - mean_absolute_error: 2.7534 - mean_squared_error: 14.2735 - val_loss: 19.3582 - val_mean_absolute_error: 3.2286 - val_mean_squared_error: 19.3582
# Epoch 30/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 14.2622 - mean_absolute_error: 2.7084 - mean_squared_error: 14.2622 - val_loss: 19.3573 - val_mean_absolute_error: 3.2262 - val_mean_squared_error: 19.3573
# Epoch 31/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 13.7374 - mean_absolute_error: 2.7130 - mean_squared_error: 13.7374 - val_loss: 18.9139 - val_mean_absolute_error: 3.2016 - val_mean_squared_error: 18.9139
# Epoch 32/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 13.6090 - mean_absolute_error: 2.6779 - mean_squared_error: 13.6090 - val_loss: 18.5811 - val_mean_absolute_error: 3.1665 - val_mean_squared_error: 18.5811
# Epoch 33/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 13.2384 - mean_absolute_error: 2.6222 - mean_squared_error: 13.2384 - val_loss: 19.0555 - val_mean_absolute_error: 3.2035 - val_mean_squared_error: 19.0555
# Epoch 34/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 13.0663 - mean_absolute_error: 2.6134 - mean_squared_error: 13.0663 - val_loss: 18.6733 - val_mean_absolute_error: 3.1823 - val_mean_squared_error: 18.6733
# Epoch 35/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 12.8180 - mean_absolute_error: 2.5947 - mean_squared_error: 12.8180 - val_loss: 18.4512 - val_mean_absolute_error: 3.1560 - val_mean_squared_error: 18.4512
# Epoch 36/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12.8017 - mean_absolute_error: 2.5886 - mean_squared_error: 12.8017 - val_loss: 18.2552 - val_mean_absolute_error: 3.1329 - val_mean_squared_error: 18.2552
# Epoch 37/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 12.4676 - mean_absolute_error: 2.5678 - mean_squared_error: 12.4676 - val_loss: 18.3394 - val_mean_absolute_error: 3.1611 - val_mean_squared_error: 18.3394
# Epoch 38/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 12.3817 - mean_absolute_error: 2.5670 - mean_squared_error: 12.3817 - val_loss: 18.0887 - val_mean_absolute_error: 3.1169 - val_mean_squared_error: 18.0887
# Epoch 39/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12.2575 - mean_absolute_error: 2.5360 - mean_squared_error: 12.2575 - val_loss: 18.1815 - val_mean_absolute_error: 3.1346 - val_mean_squared_error: 18.1815
# Epoch 40/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12.7009 - mean_absolute_error: 2.5416 - mean_squared_error: 12.7009 - val_loss: 18.6081 - val_mean_absolute_error: 3.1635 - val_mean_squared_error: 18.6081
# Epoch 41/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 12.1839 - mean_absolute_error: 2.5266 - mean_squared_error: 12.1839 - val_loss: 17.7265 - val_mean_absolute_error: 3.0828 - val_mean_squared_error: 17.7265
# Epoch 42/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 11.8464 - mean_absolute_error: 2.5090 - mean_squared_error: 11.8464 - val_loss: 17.9112 - val_mean_absolute_error: 3.1133 - val_mean_squared_error: 17.9112
# Epoch 43/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 11.8554 - mean_absolute_error: 2.5199 - mean_squared_error: 11.8554 - val_loss: 17.1599 - val_mean_absolute_error: 3.0477 - val_mean_squared_error: 17.1599
# Epoch 44/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 11.6169 - mean_absolute_error: 2.4796 - mean_squared_error: 11.6169 - val_loss: 17.5577 - val_mean_absolute_error: 3.0853 - val_mean_squared_error: 17.5577
# Epoch 45/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11.5745 - mean_absolute_error: 2.4539 - mean_squared_error: 11.5745 - val_loss: 17.1684 - val_mean_absolute_error: 3.0479 - val_mean_squared_error: 17.1684
# Epoch 46/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.3071 - mean_absolute_error: 2.4303 - mean_squared_error: 11.3071 - val_loss: 17.6480 - val_mean_absolute_error: 3.0949 - val_mean_squared_error: 17.6480
# Epoch 47/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 11.2232 - mean_absolute_error: 2.4377 - mean_squared_error: 11.2232 - val_loss: 17.1597 - val_mean_absolute_error: 3.0652 - val_mean_squared_error: 17.1597
# Epoch 48/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 11.1908 - mean_absolute_error: 2.4092 - mean_squared_error: 11.1908 - val_loss: 17.2558 - val_mean_absolute_error: 3.0820 - val_mean_squared_error: 17.2558
# Epoch 49/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.9589 - mean_absolute_error: 2.3932 - mean_squared_error: 10.9589 - val_loss: 16.6742 - val_mean_absolute_error: 3.0326 - val_mean_squared_error: 16.6742
# Epoch 50/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.9218 - mean_absolute_error: 2.3983 - mean_squared_error: 10.9218 - val_loss: 16.9611 - val_mean_absolute_error: 3.0654 - val_mean_squared_error: 16.9611
# Epoch 51/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.7471 - mean_absolute_error: 2.3777 - mean_squared_error: 10.7471 - val_loss: 16.7087 - val_mean_absolute_error: 3.0478 - val_mean_squared_error: 16.7087
# Epoch 52/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.6561 - mean_absolute_error: 2.3606 - mean_squared_error: 10.6561 - val_loss: 16.7686 - val_mean_absolute_error: 3.0433 - val_mean_squared_error: 16.7686
# Epoch 53/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.5710 - mean_absolute_error: 2.3551 - mean_squared_error: 10.5710 - val_loss: 16.7513 - val_mean_absolute_error: 3.0451 - val_mean_squared_error: 16.7513
# Epoch 54/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.6125 - mean_absolute_error: 2.3907 - mean_squared_error: 10.6125 - val_loss: 16.7799 - val_mean_absolute_error: 3.0488 - val_mean_squared_error: 16.7799
# Epoch 55/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 10.3793 - mean_absolute_error: 2.3435 - mean_squared_error: 10.3793 - val_loss: 16.3633 - val_mean_absolute_error: 3.0046 - val_mean_squared_error: 16.3633
# Epoch 56/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.3905 - mean_absolute_error: 2.3274 - mean_squared_error: 10.3905 - val_loss: 16.1680 - val_mean_absolute_error: 2.9912 - val_mean_squared_error: 16.1680
# Epoch 57/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.2097 - mean_absolute_error: 2.3254 - mean_squared_error: 10.2097 - val_loss: 16.0085 - val_mean_absolute_error: 2.9796 - val_mean_squared_error: 16.0085
# Epoch 58/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.2373 - mean_absolute_error: 2.3206 - mean_squared_error: 10.2373 - val_loss: 16.1329 - val_mean_absolute_error: 2.9867 - val_mean_squared_error: 16.1329
# Epoch 59/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 10.0397 - mean_absolute_error: 2.3003 - mean_squared_error: 10.0397 - val_loss: 16.2697 - val_mean_absolute_error: 3.0147 - val_mean_squared_error: 16.2697
# Epoch 60/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.9431 - mean_absolute_error: 2.3087 - mean_squared_error: 9.9431 - val_loss: 15.7806 - val_mean_absolute_error: 2.9557 - val_mean_squared_error: 15.7806
# Epoch 61/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.9382 - mean_absolute_error: 2.2833 - mean_squared_error: 9.9382 - val_loss: 15.8881 - val_mean_absolute_error: 2.9784 - val_mean_squared_error: 15.8881
# Epoch 62/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.8791 - mean_absolute_error: 2.3032 - mean_squared_error: 9.8791 - val_loss: 16.2307 - val_mean_absolute_error: 3.0031 - val_mean_squared_error: 16.2307
# Epoch 63/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.7708 - mean_absolute_error: 2.2722 - mean_squared_error: 9.7708 - val_loss: 15.9645 - val_mean_absolute_error: 2.9861 - val_mean_squared_error: 15.9645
# Epoch 64/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.7085 - mean_absolute_error: 2.2679 - mean_squared_error: 9.7085 - val_loss: 15.6940 - val_mean_absolute_error: 2.9564 - val_mean_squared_error: 15.6940
# Epoch 65/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.6185 - mean_absolute_error: 2.2673 - mean_squared_error: 9.6185 - val_loss: 15.6852 - val_mean_absolute_error: 2.9492 - val_mean_squared_error: 15.6852
# Epoch 66/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.7276 - mean_absolute_error: 2.2787 - mean_squared_error: 9.7276 - val_loss: 15.6828 - val_mean_absolute_error: 2.9462 - val_mean_squared_error: 15.6828
# Epoch 67/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.4197 - mean_absolute_error: 2.2393 - mean_squared_error: 9.4197 - val_loss: 15.9209 - val_mean_absolute_error: 2.9827 - val_mean_squared_error: 15.9209
# Epoch 68/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.4786 - mean_absolute_error: 2.2300 - mean_squared_error: 9.4786 - val_loss: 15.4153 - val_mean_absolute_error: 2.9259 - val_mean_squared_error: 15.4153
# Epoch 69/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.3955 - mean_absolute_error: 2.2362 - mean_squared_error: 9.3955 - val_loss: 15.9429 - val_mean_absolute_error: 2.9486 - val_mean_squared_error: 15.9429
# Epoch 70/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.4980 - mean_absolute_error: 2.2345 - mean_squared_error: 9.4980 - val_loss: 15.5811 - val_mean_absolute_error: 2.9288 - val_mean_squared_error: 15.5811
# Epoch 71/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.2408 - mean_absolute_error: 2.2289 - mean_squared_error: 9.2408 - val_loss: 15.3072 - val_mean_absolute_error: 2.8942 - val_mean_squared_error: 15.3072
# Epoch 72/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.2744 - mean_absolute_error: 2.2378 - mean_squared_error: 9.2744 - val_loss: 15.5354 - val_mean_absolute_error: 2.9211 - val_mean_squared_error: 15.5354
# Epoch 73/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.1422 - mean_absolute_error: 2.2558 - mean_squared_error: 9.1422 - val_loss: 14.5968 - val_mean_absolute_error: 2.8380 - val_mean_squared_error: 14.5968
# Epoch 74/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 9.0120 - mean_absolute_error: 2.2082 - mean_squared_error: 9.0120 - val_loss: 15.0998 - val_mean_absolute_error: 2.8899 - val_mean_squared_error: 15.0998
# Epoch 75/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 9.0558 - mean_absolute_error: 2.2301 - mean_squared_error: 9.0558 - val_loss: 15.0997 - val_mean_absolute_error: 2.8899 - val_mean_squared_error: 15.0997
# Epoch 76/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.9081 - mean_absolute_error: 2.2048 - mean_squared_error: 8.9081 - val_loss: 14.9097 - val_mean_absolute_error: 2.8698 - val_mean_squared_error: 14.9097
# Epoch 77/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 9.0501 - mean_absolute_error: 2.2157 - mean_squared_error: 9.0501 - val_loss: 14.5254 - val_mean_absolute_error: 2.8346 - val_mean_squared_error: 14.5254
# Epoch 78/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.8360 - mean_absolute_error: 2.1684 - mean_squared_error: 8.8360 - val_loss: 15.4689 - val_mean_absolute_error: 2.9342 - val_mean_squared_error: 15.4689
# Epoch 79/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.6013 - mean_absolute_error: 2.1617 - mean_squared_error: 8.6013 - val_loss: 14.7174 - val_mean_absolute_error: 2.8620 - val_mean_squared_error: 14.7174
# Epoch 80/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 8.6476 - mean_absolute_error: 2.1796 - mean_squared_error: 8.6476 - val_loss: 14.4888 - val_mean_absolute_error: 2.8369 - val_mean_squared_error: 14.4888
# Epoch 81/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.6315 - mean_absolute_error: 2.1716 - mean_squared_error: 8.6315 - val_loss: 15.1327 - val_mean_absolute_error: 2.8842 - val_mean_squared_error: 15.1327
# Epoch 82/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.5932 - mean_absolute_error: 2.1688 - mean_squared_error: 8.5932 - val_loss: 14.6570 - val_mean_absolute_error: 2.8489 - val_mean_squared_error: 14.6570
# Epoch 83/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.4506 - mean_absolute_error: 2.1346 - mean_squared_error: 8.4506 - val_loss: 14.9113 - val_mean_absolute_error: 2.8655 - val_mean_squared_error: 14.9113
# Epoch 84/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.3984 - mean_absolute_error: 2.1447 - mean_squared_error: 8.3984 - val_loss: 14.5212 - val_mean_absolute_error: 2.8482 - val_mean_squared_error: 14.5212
# Epoch 85/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.6177 - mean_absolute_error: 2.2187 - mean_squared_error: 8.6177 - val_loss: 14.6796 - val_mean_absolute_error: 2.8370 - val_mean_squared_error: 14.6796
# Epoch 86/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.5109 - mean_absolute_error: 2.1714 - mean_squared_error: 8.5109 - val_loss: 14.5390 - val_mean_absolute_error: 2.8353 - val_mean_squared_error: 14.5390
# Epoch 87/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.6196 - mean_absolute_error: 2.1766 - mean_squared_error: 8.6196 - val_loss: 14.8897 - val_mean_absolute_error: 2.8644 - val_mean_squared_error: 14.8897
# Epoch 88/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 8.2729 - mean_absolute_error: 2.1446 - mean_squared_error: 8.2729 - val_loss: 14.8378 - val_mean_absolute_error: 2.8626 - val_mean_squared_error: 14.8378
# Epoch 89/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 8.2654 - mean_absolute_error: 2.1344 - mean_squared_error: 8.2654 - val_loss: 14.7378 - val_mean_absolute_error: 2.8498 - val_mean_squared_error: 14.7378
# Epoch 90/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 8.2077 - mean_absolute_error: 2.1516 - mean_squared_error: 8.2077 - val_loss: 14.2657 - val_mean_absolute_error: 2.7956 - val_mean_squared_error: 14.2657
# Epoch 91/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.1941 - mean_absolute_error: 2.1134 - mean_squared_error: 8.1941 - val_loss: 14.3099 - val_mean_absolute_error: 2.8028 - val_mean_squared_error: 14.3099
# Epoch 92/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 8.2578 - mean_absolute_error: 2.1830 - mean_squared_error: 8.2578 - val_loss: 14.5090 - val_mean_absolute_error: 2.8289 - val_mean_squared_error: 14.5090
# Epoch 93/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 7.9085 - mean_absolute_error: 2.0897 - mean_squared_error: 7.9085 - val_loss: 14.2682 - val_mean_absolute_error: 2.7881 - val_mean_squared_error: 14.2682
# Epoch 94/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.9401 - mean_absolute_error: 2.1119 - mean_squared_error: 7.9401 - val_loss: 13.9336 - val_mean_absolute_error: 2.7625 - val_mean_squared_error: 13.9336
# Epoch 95/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.9806 - mean_absolute_error: 2.0912 - mean_squared_error: 7.9806 - val_loss: 14.4907 - val_mean_absolute_error: 2.8235 - val_mean_squared_error: 14.4907
# Epoch 96/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.7973 - mean_absolute_error: 2.0831 - mean_squared_error: 7.7973 - val_loss: 14.5049 - val_mean_absolute_error: 2.8227 - val_mean_squared_error: 14.5049
# Epoch 97/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.7845 - mean_absolute_error: 2.0959 - mean_squared_error: 7.7845 - val_loss: 13.7954 - val_mean_absolute_error: 2.7576 - val_mean_squared_error: 13.7954
# Epoch 98/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.9207 - mean_absolute_error: 2.1084 - mean_squared_error: 7.9207 - val_loss: 14.0354 - val_mean_absolute_error: 2.7652 - val_mean_squared_error: 14.0354
# Epoch 99/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 7.8248 - mean_absolute_error: 2.0572 - mean_squared_error: 7.8248 - val_loss: 14.3860 - val_mean_absolute_error: 2.8153 - val_mean_squared_error: 14.3860
# Epoch 100/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 7.7719 - mean_absolute_error: 2.1040 - mean_squared_error: 7.7719 - val_loss: 14.0494 - val_mean_absolute_error: 2.7988 - val_mean_squared_error: 14.0494

# %%
from sklearn.metrics import classification_report, mean_absolute_error, mean_squared_error

# %%
y_pred = model.predict(x_test_scaled)
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step

# %%
y_pred.shape
# Out:
# (102, 1)

# %%
y_test.shape
# Out:
# (102,)

# %%
y_pred = y_pred.flatten()
y_pred.shape
# Out:
# (102,)

# %%
print(mean_absolute_error(y_test, y_pred))
# Out:
# 2.317354060154335

# %%
print(mean_squared_error(y_test, y_pred))
# Out:
# 13.243795006876386

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8, 6))
plt.plot(history.history['loss'], label="loss", color="red")
plt.plot(history.history['val_loss'], label="val_loss", color="green")
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred)
plt.grid()
plt.show()

# %%
import inspect
print(inspect.getsource(model.fit))
# Out:
#     @traceback_utils.filter_traceback
#     def fit(
#         self,
#         x=None,
#         y=None,
#         batch_size=None,
#         epochs=1,
#         verbose="auto",
#         callbacks=None,
#         validation_split=0.0,
#         validation_data=None,
#         shuffle=True,
#         class_weight=None,
#         sample_weight=None,
#         initial_epoch=0,
#         steps_per_epoch=None,
#         validation_steps=None,
#         validation_batch_size=None,
#         validation_freq=1,
#     ):
#         self._assert_compile_called("fit")
#         # Possibly cap epochs for debugging runs.
#         max_epochs = config.max_epochs()
#         if max_epochs and max_epochs < epochs:
#             warnings.warn("Limiting epochs to %d" % max_epochs)
#             epochs = max_epochs
#         # TODO: respect compiled trainable state
#         self._eval_epoch_iterator = None
#         if validation_split and validation_data is None:
#             # Create the validation data using the training data. Only supported
#             # for TF/numpy/jax arrays.
#             (
#                 (x, y, sample_weight),
#                 validation_data,
#             ) = array_slicing.train_validation_split(
#                 (x, y, sample_weight), validation_split=validation_split
#             )
#
#         if validation_data is not None:
#             (
#                 val_x,
#                 val_y,
#                 val_sample_weight,
#             ) = data_adapter_utils.unpack_x_y_sample_weight(validation_data)
#
#         # Create an iterator that yields batches for one epoch.
#         epoch_iterator = TFEpochIterator(
#             x=x,
#             y=y,
#             sample_weight=sample_weight,
#             batch_size=batch_size,
#             steps_per_epoch=steps_per_epoch,
#             shuffle=shuffle,
#             class_weight=class_weight,
#             distribute_strategy=self.distribute_strategy,
#             steps_per_execution=self.steps_per_execution,
#         )
#
#         self._maybe_symbolic_build(iterator=epoch_iterator)
#         epoch_iterator.reset()
#
#         # Container that configures and calls callbacks.
#         if not isinstance(callbacks, callbacks_module.CallbackList):
#             callbacks = callbacks_module.CallbackList(
#                 callbacks,
#                 add_history=True,
#                 add_progbar=verbose != 0,
#                 verbose=verbose,
#                 epochs=epochs,
#                 steps=epoch_iterator.num_batches,
#                 model=self,
#             )
#
#         self.stop_training = False
#         self.make_train_function()
#         callbacks.on_train_begin()
#         training_logs = None
#         logs = {}
#         initial_epoch = self._initial_epoch or initial_epoch
#         for epoch in range(initial_epoch, epochs):
#             self.reset_metrics()
#             callbacks.on_epoch_begin(epoch)
#             with epoch_iterator.catch_stop_iteration():
#                 for begin_step, end_step, iterator in epoch_iterator:
#                     callbacks.on_train_batch_begin(begin_step)
#                     logs = self.train_function(iterator)
#                     callbacks.on_train_batch_end(end_step, logs)
#                     if self.stop_training:
#                         break
#
#             # Override with model metrics instead of last step logs if needed.
#             epoch_logs = dict(self._get_metrics_result_or_logs(logs))
#
#             # Run validation.
#             if validation_data is not None and self._should_eval(
#                 epoch, validation_freq
#             ):
#                 # Create EpochIterator for evaluation and cache it.
#                 if getattr(self, "_eval_epoch_iterator", None) is None:
#                     self._eval_epoch_iterator = TFEpochIterator(
#                         x=val_x,
#                         y=val_y,
#                         sample_weight=val_sample_weight,
#                         batch_size=validation_batch_size or batch_size,
#                         distribute_strategy=self.distribute_strategy,
#                         steps_per_execution=self.steps_per_execution,
#                         steps_per_epoch=validation_steps,
#                         shuffle=False,
#                     )
#                 val_logs = self.evaluate(
#                     x=val_x,
#                     y=val_y,
#                     sample_weight=val_sample_weight,
#                     batch_size=validation_batch_size or batch_size,
#                     steps=validation_steps,
#                     callbacks=callbacks,
#                     return_dict=True,
#                     _use_cached_eval_dataset=True,
#                 )
#                 val_logs = {
#                     f"val_{name}": val for name, val in val_logs.items()
#                 }
#                 epoch_logs.update(val_logs)
#
#             callbacks.on_epoch_end(epoch, epoch_logs)
#             training_logs = epoch_logs
#             if self.stop_training:
#                 break
#
#         if (
#             isinstance(self.optimizer, optimizers_module.Optimizer)
#             and epochs > 0
#         ):
#             self.optimizer.finalize_variable_values(self.trainable_weights)
#
#         # If _eval_epoch_iterator exists, delete it after all epochs are done.
#         if getattr(self, "_eval_epoch_iterator", None) is not None:
#             del self._eval_epoch_iterator
#         callbacks.on_train_end(logs=training_logs)
#         return self.history
